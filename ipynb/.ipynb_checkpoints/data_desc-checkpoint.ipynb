# %%
abalone = read.csv('http://archive.ics.uci.edu/ml/machine-learning-databases/abalone/abalone.data', head = F, sep=",")

# %%
colnames(abalone) <- c('Sex','Length','Diameter','Height','Whole_weight','Shucked_weight','Viscera_weight','Shell_weight','Rings')
head(abalone, 10)
# Out:
#    Sex Length Diameter Height Whole_weight Shucked_weight Viscera_weight
# 1  M   0.455  0.365    0.095  0.5140       0.2245         0.1010
# 2  M   0.350  0.265    0.090  0.2255       0.0995         0.0485
# 3  F   0.530  0.420    0.135  0.6770       0.2565         0.1415
# 4  M   0.440  0.365    0.125  0.5160       0.2155         0.1140
# 5  I   0.330  0.255    0.080  0.2050       0.0895         0.0395
# 6  I   0.425  0.300    0.095  0.3515       0.1410         0.0775
# 7  F   0.530  0.415    0.150  0.7775       0.2370         0.1415
# 8  F   0.545  0.425    0.125  0.7680       0.2940         0.1495
# 9  M   0.475  0.370    0.125  0.5095       0.2165         0.1125
# 10 F   0.550  0.440    0.150  0.8945       0.3145         0.1510
#    Shell_weight Rings
# 1  0.150        15
# 2  0.070         7
# 3  0.210         9
# 4  0.155        10
# 5  0.055         7
# 6  0.120         8
# 7  0.330        20
# 8  0.260        16
# 9  0.165         9
# 10 0.320        19

# %%
dim(abalone)
# Out:
# [1] 4177    9

# %%
abalone[abalone$Height==0,]
# Out:
#      Sex Length Diameter Height Whole_weight Shucked_weight Viscera_weight
# 1258 I   0.430  0.34     0      0.428        0.2065         0.0860
# 3997 I   0.315  0.23     0      0.134        0.0575         0.0285
#      Shell_weight Rings
# 1258 0.1150       8
# 3997 0.3505       6

# %%
abalone$Height[abalone$Height==0] = NA

# %%
summary(abalone)
# Out:
#  Sex          Length         Diameter          Height        Whole_weight
#  F:1307   Min.   :0.075   Min.   :0.0550   Min.   :0.0100   Min.   :0.0020
#  I:1342   1st Qu.:0.450   1st Qu.:0.3500   1st Qu.:0.1150   1st Qu.:0.4415
#  M:1528   Median :0.545   Median :0.4250   Median :0.1400   Median :0.7995
#           Mean   :0.524   Mean   :0.4079   Mean   :0.1396   Mean   :0.8287
#           3rd Qu.:0.615   3rd Qu.:0.4800   3rd Qu.:0.1650   3rd Qu.:1.1530
#           Max.   :0.815   Max.   :0.6500   Max.   :1.1300   Max.   :2.8255
#                                            NA's   :2
#  Shucked_weight   Viscera_weight    Shell_weight        Rings
#  Min.   :0.0010   Min.   :0.0005   Min.   :0.0015   Min.   : 1.000
#  1st Qu.:0.1860   1st Qu.:0.0935   1st Qu.:0.1300   1st Qu.: 8.000
#  Median :0.3360   Median :0.1710   Median :0.2340   Median : 9.000
#  Mean   :0.3594   Mean   :0.1806   Mean   :0.2388   Mean   : 9.934
# ...

# %%
object.size(abalone)
# Out:
# 269528 bytes

# %%
str(abalone)
# Out:
# 'data.frame':	4177 obs. of  9 variables:
#  $ Sex           : Factor w/ 3 levels "F","I","M": 3 3 1 3 2 2 1 1 3 1 ...
#  $ Length        : num  0.455 0.35 0.53 0.44 0.33 0.425 0.53 0.545 0.475 0.55 ...
#  $ Diameter      : num  0.365 0.265 0.42 0.365 0.255 0.3 0.415 0.425 0.37 0.44 ...
#  $ Height        : num  0.095 0.09 0.135 0.125 0.08 0.095 0.15 0.125 0.125 0.15 ...
#  $ Whole_weight  : num  0.514 0.226 0.677 0.516 0.205 ...
#  $ Shucked_weight: num  0.2245 0.0995 0.2565 0.2155 0.0895 ...
#  $ Viscera_weight: num  0.101 0.0485 0.1415 0.114 0.0395 ...
#  $ Shell_weight  : num  0.15 0.07 0.21 0.155 0.055 0.12 0.33 0.26 0.165 0.32 ...
#  $ Rings         : int  15 7 9 10 7 8 20 16 9 19 ...

# %%
unlist(lapply(abalone, class))
# Out:
#            Sex         Length       Diameter         Height   Whole_weight
#       "factor"      "numeric"      "numeric"      "numeric"      "numeric"
# Shucked_weight Viscera_weight   Shell_weight          Rings
#      "numeric"      "numeric"      "numeric"      "integer"

# %%
pairs(abalone)
# Out:
# plot without title

# %%
library(repr)
options(repr.plot.width=12, repr.plot.height=6)
hist(abalone$Rings, freq = T)
lines(density(abalone$Rings))
# Out:
# Plot with title “Histogram of abalone$Rings”

# %%
library(repr)
options(repr.plot.width=12, repr.plot.height=6)
hist(abalone$Height, freq = F)
# Out:
# Plot with title “Histogram of abalone$Height”

# %%
library(repr)
options(repr.plot.width=12, repr.plot.height=6)
hist(abalone$Viscera_weight, freq = F)
lines(density(abalone$Viscera_weight))
# Out:
# Plot with title “Histogram of abalone$Viscera_weight”

# %%
library(repr)
options(repr.plot.width=12, repr.plot.height=6)
hist(abalone$Length, freq = F)
lines(density(abalone$Length))
# Out:
# Plot with title “Histogram of abalone$Length”

# %%
install.packages("usdm")
# Out:
# Updating HTML index of packages in '.Library'
# Making 'packages.html' ... done

# %%
install.packages("corrplot")
install.packages("knitr")
# Out:
# Updating HTML index of packages in '.Library'
# Making 'packages.html' ... done
# Updating HTML index of packages in '.Library'
# Making 'packages.html' ... done

# %%
library(usdm)
vif(abalone)
# Out:
# Warning message in model.response(mf, "numeric"):
# “using type = "numeric" with a factor response will be ignored”Warning message in Ops.factor(y, z$residuals):
# “‘-’ not meaningful for factors”Warning message in Ops.factor(r, 2):
# “‘^’ not meaningful for factors”
#   Variables      VIF
# 1 Sex                    NA
# 2 Length          40.915529
# 3 Diameter        42.624925
# 4 Height           3.644180
# 5 Whole_weight   115.342304
# 6 Shucked_weight  32.791096
# 7 Viscera_weight  17.764832
# 8 Shell_weight    22.173910
# 9 Rings            2.163835

# %%
abalone_model <- lm( Rings ~ Length + Height + Viscera_weight + Sex, data = abalone)
summary(abalone_model)
# Out:
# Call:
# lm(formula = Rings ~ Length + Height + Viscera_weight + Sex,
#     data = abalone)
#
# Residuals:
#      Min       1Q   Median       3Q      Max
# -24.5855  -1.5960  -0.5637   0.8411  16.5186
#
# Coefficients:
#                Estimate Std. Error t value Pr(>|t|)
# (Intercept)     3.21887    0.31096  10.351  < 2e-16 ***
# Length          8.96888    0.85290  10.516  < 2e-16 ***
# Height         22.76892    1.75676  12.961  < 2e-16 ***
# Viscera_weight -3.81953    0.87602  -4.360 1.33e-05 ***
# SexI           -1.27520    0.11903 -10.713  < 2e-16 ***
# SexM           -0.17192    0.09751  -1.763   0.0779 .
# ---
# Signif. codes:  0 ‘***’ 0.001 ‘**’ 0.01 ‘*’ 0.05 ‘.’ 0.1 ‘ ’ 1
#
# Residual standard error: 2.58 on 4169 degrees of freedom
#   (2 observations deleted due to missingness)
# Multiple R-squared:  0.3606,	Adjusted R-squared:  0.3598
# F-statistic: 470.2 on 5 and 4169 DF,  p-value: < 2.2e-16

# %%
plot(abalone_model, which = 1, id.n = 5)
# Out:
# Plot with title “”

# %%
plot(abalone_model, which = 2, id.n = 5)
# Out:
# Plot with title “”

# %%
plot(abalone_model, which = 3, id.n = 5)
# Out:
# Plot with title “”

# %%
plot(abalone_model, which = 4, id.n = 5)
# Out:
# Plot with title “”

# %%
plot(abalone_model, which = 5, id.n = 5)
# Out:
# Plot with title “”

# %%
library(knitr)
kable(coefficients(abalone_model), col.names = "\u03b2~n~")
# Out:
# |               |      β~n~|
# |:--------------|---------:|
# |(Intercept)    |  3.218875|
# |Length         |  8.968878|
# |Height         | 22.768919|
# |Viscera_weight | -3.819527|
# |SexI           | -1.275202|
# |SexM           | -0.171923|

# %% [markdown]
# Rings=3.2189+8.9689(Length)+22.7689(Height)−3.8195(Viscera_weight)−1.2752(SexI)−0.1719(SexM)+ϵ
